# %%
##Logan Lauton
##Exploratory Data Analysis

##importing required packages for this exploratory data analysis
import requests
import oracledb
import getpass
import cx_Oracle
import os
import pandas as pd
import matplotlib.pyplot as plt

##connecting to the db as we did in grab_data.ipynb
password = getpass.getpass("Enter DB Password")
wallet_password = getpass.getpass("Enter Wallet Password")

os.environ.get('TNS_ADMIN')
connection = oracledb.connect(
    user="admin",
    password=password,
    dsn = "ltl3y0m4d7of29l1_high",
    config_dir="./config",
    wallet_location="./config",
    wallet_password=wallet_password)
print("Successfully connected to Oracle Database")

cursor = connection.cursor()

##selecting everything from the calls table and creating a df
rs = cursor.execute("SELECT * FROM CALLS")
df = pd.DataFrame(rs.fetchall())
print('Successfully imported table from Oracle Database')
# Out:
# Enter DB Password········
# Enter Wallet Password········
# Successfully connected to Oracle Database
# Successfully imported table from Oracle Database

# %%
##properly naming the columns
df.columns = ['Call Number' , 'Date/Time' , 'Address' , 'District' , 'Nature of Call' , 'Status' , 'Latitude' , 'Longitude']

# %%
df
# Out:
#       Call Number               Date/Time                           Address  \
# 0       230311239  01/31/2023 04:42:12 PM    N 35TH ST / W PARK HILL AV,MKE
# 1       230311241  01/31/2023 04:42:05 PM                2222 S 37TH ST,MKE
# 2       230311230  01/31/2023 04:39:09 PM            212 W WISCONSIN AV,MKE
# 3       230311236  01/31/2023 04:38:12 PM             4204 W CAPITOL DR,MKE
# 4       230311235  01/31/2023 04:36:54 PM  N TEUTONIA AV / W VILLARD AV,MKE
# ...           ...                     ...                               ...
# 40973   230580743  02/27/2023 01:30:10 PM               5033 W KEEFE AV,MKE
# 40974   230580741  02/27/2023 01:29:08 PM            6680 N TEUTONIA AV,MKE
# 40975   230580740  02/27/2023 01:29:02 PM                2333 N 49TH ST,MKE
# 40976   230580739  02/27/2023 01:28:24 PM                1439 S 34TH ST,MKE
# 40977   230580738  02/27/2023 01:27:56 PM               4777 N 124TH ST,BUT
#
#       District   Nature of Call                        Status   Latitude  \
# 0            3           ACC PI           Service in Progress  43.085368
# 1            2    INVESTIGATION          Assignment Completed  43.004218
# 2            1   SUSP PERS/AUTO  Unable to Locate Complainant  43.039249
# 3            7     TRAFFIC STOP                       Advised  43.089974
# 4            7    INVESTIGATION          Assignment Completed  43.071124
# ...        ...              ...                           ...        ...
# 40973        7     TRAFFIC STOP           Service in Progress  43.082412
# 40974        4  ASSIGN-ADMN MPD           Service in Progress  43.138814
# 40975        3   RETURN STATION          Assignment Completed  43.061594
# 40976        2    HOME VISIT DV          Assignment Completed  43.016092
# 40977        6  ASSIGN-ADMN MPD           Service in Progress  43.162412
#
#        Longitude
# 0     -87.957141
# 1     -87.960256
# 2     -87.913401
# 3     -87.965580
# 4     -87.930350
# ...          ...
# 40973 -87.976831
# 40974 -87.953077
# 40975 -87.975478
# 40976 -87.956694
# 40977 -88.064089
#
# [40978 rows x 8 columns]

# %%
df.to_csv('Tableau_data_2_26_23.csv', index = True)

# %%
(df.groupby(['Address']).size()).sort_values(ascending = False)
# Out:
# Address
# 707 S 1ST ST,MKE           95
# 901 N 9TH ST,MKE           67
# 3000 W CANAL ST,MKE        66
# 3127 N 21ST ST,MKE         65
# 5000 W CHAMBERS ST,MKE     64
#                            ..
# 4554 W WOOLWORTH AV,MKE     1
# 4550 W CLARKE ST,MKE        1
# 454 N VAN BUREN ST,MKE      1
# 4535 N HOUSTON AV,MKE       1
# WB VILLARD                  1
# Length: 7066, dtype: int64

# %%
##values are addresses of police internal affairs
values = ["749 W STATE ST,MKE", "245 W LINCOLN AV,MKE", "2333 N 49TH ST,MKE", "6929 W SILVER SPRING DR,MKE",
          "2920 N VEL R PHILLIPS AV,MKE", "3006 S 27TH ST,MKE", "3626 W FOND DU LAC AV,MKE", "4715 W VLIET ST,MKE",
         "6680 N TEUTONIA AV,MKE","949 N 9TH ST,MKE","3811 W LINCOLN AV,MKE","4777 N 124TH ST,BUT"]

##drop rows that contain any value in the list
df = df[df.Address.isin(values) == False]

##by doing this we can accurately represent police community involvement

# %%
(df.groupby(['Nature of Call']).size()).sort_values(ascending = False)
# Out:
# Nature of Call
# WELFARE CITIZEN     1779
# ACC PDO             1131
# CALL FOR POLICE     1055
# BATTERY             1027
# THREAT               972
#                     ...
# PLANT CAR              2
# GAS LEAK               2
# CONT DEL MINOR         2
# METH LAB               1
# WATER MAIN BREAK       1
# Length: 122, dtype: int64

# %%
##values appear to be calls of police internal affairs
values = ["TRAFFIC STOP", "TRBL W/SUBJ", "PATROL","SHOTSPOTTER","PARK AND WALK",
         "INVESTIGATION","ENTRY","BUSINESS CHECK","FOLLOW UP", "SPECIAL ASSIGN",
         "TRAFFIC LASER","OUT OF SERVICE","ACC PDO", "ACC PI", "ACC UNKN INJ"]

##drop rows that contain any value in the list
df = df[df['Nature of Call'].isin(values) == False]

##by doing this we can accurately represent police community involvement

# %%
##counting occurrences of District in the df
occur = df.groupby(['District']).size()

##creating my x and y variables for a basic bar chart
##x is the district number
##y is the number of calls that occurs shown above
x = [1 , 2 , 3 , 4 , 5 , 6 , 7]
y = occur[0:7]
 
##function to add value labels to bar chart
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i+1, y[i]//2, y[i], ha = 'center', color = 'white')    
        
##building basic bar chart        
plt.figure(figsize = (10,5))
plt.bar(x , y , color = 'lightblue')
plt.title('Number of Calls per Police District')
plt.xlabel('District')
plt.ylabel('# of calls')

##using function to add numbers to plot
addlabels(x , y)

##showing the final plot
plt.show()

# %%
##gathering the number of occurences of specific crimes
occur_noc = df.groupby(['Nature of Call']).size()
##sorting the occurences in descending order
occur_noc = occur_noc.sort_values(ascending = False)
##placing the data into a df
noc_occur = pd.DataFrame(occur_noc)
##properly naming the column
noc_occur.columns = ['Number of Occurences']

##creating my x and y variables for a basic bar chart
##x is the Occurence Type
##y is the number of calls that occurs shown above
x_noc = list(noc_occur[0:9].index.values)
for i in list(noc_occur[0:9]):
    # show the list of values  
    y_noc = noc_occur[i].tolist()

##building basic bar chart  
fig, ax = plt.subplots(figsize = (10,5))
bars = ax.barh(x_noc , y_noc[0:9], color = 'lightblue')

for i in ax.containers:
    ax.bar_label(bars, label_type = 'center', color = 'white')

##showing the final plot
plt.show()

# %%
occur_noc.to_csv('Nature of Calls.csv')

# %%
##Test to determine ethical considerations - Logan
##On February 7th, 2023 at appriximately 1:15am Milwaukee Police Officer 
##Peter Jerving was shot and killed in action. This is test is to determine 
##if we are able to find the call that he responded to earlier in the night
##and if we are able to what ethical quesitons need to be asked regarding 
## that.

##removing all non-district 4 calls as that was Officer Jerving's precinct
ethic = df.drop(df[df.District != '4'].index)

##seperation of Date & Time into seperate columns to go off of reports from
##media channels
ethic['Date'] = ethic['Date/Time'].str.split('\s+').str[0]
ethic['Time'] = ethic['Date/Time'].str.split('\s+').str[1]

##selecting only the 6th and 7th of Feb as this was the time frame that
##officer Jerving would be responding to a call
ethic_06 = ethic[(ethic.Date == '02/06/2023')]
ethic_07 = ethic[(ethic.Date == '02/07/2023')]
ethic = ethic_06
ethic = ethic.append(ethic_07)


##according to https://news.yahoo.com/news/milwaukee-police-officer-shot-killed-191640738.html?guccounter=1&guce_referrer=aHR0cHM6Ly9kdWNrZHVja2dvLmNvbS8&guce_referrer_sig=AQAAAJDKo_69SdT2K6T9yiBd87LklJWdolHnCY67y_FcvJNjnuM2JagHigHu8ORBmVOR37CNW5tV4QEiDZze6On-D1Z9JLth3jgL3vzTm5iFkuOIiSm0vbEJ4gq2W5TG5a_aU9VnsPLTn2iU_qCpBzjqxxDLSMBeGhYuMGdC-9a2kvTF
##Officers were responding to the area of the 2700 block of 
##South 14th Street to check for a man wanted in connection with a robbery 
##that occurred at 11:25 a.m. Monday in the 3600 block of West Good Hope 
##Road.

##as we can see Call Number 230371702 has the address of 3632 W GOOD HOPE RD
##and the nature of call is a robbery, implying that this is the call that 
##officer Jerving responded too.
Officer_Jerving = ethic[(ethic['Call Number'] == '230371702')]

##I will export the csv of the ethic df to further investigate the logs
##and will determine if any further code/cleaning is needed.
ethic.to_csv('Ethical Issues.csv', index = True)

##after exporting and reviewing the csv I, Logan Lauton, have determined 
##that there was only one relevant call log, labeled above as 
##Officer_Jerving. I will discuss further with Dr. Michael Zimmer to
##determine where to go forward, and whether or not to share the csv in the
##git repo.

##All good

# %%
##importing required packages for this exploratory data analysis
import requests
import oracledb
import getpass
import cx_Oracle
import os
import pandas as pd
import matplotlib.pyplot as plt

##connecting to the db as we did in grab_data.ipynb
password = getpass.getpass("Enter DB Password")
wallet_password = getpass.getpass("Enter Wallet Password")

os.environ.get('TNS_ADMIN')
connection = oracledb.connect(
    user="admin",
    password=password,
    dsn = "ltl3y0m4d7of29l1_high",
    config_dir="./config",
    wallet_location="./config",
    wallet_password=wallet_password)
print("Successfully connected to Oracle Database")

cursor = connection.cursor()

##selecting everything from the calls table and creating a df
rs = cursor.execute("SELECT * FROM HISTORIC_REAL_ESTATE")
df_red = pd.DataFrame(rs.fetchall())
print("Successfully imported data")

##replacing names of columns
df_red.columns =['PropertyID','PropType','Address','District','Sale_date','Sale_price']

##exporting as there is 56,000+ values which makes it incredibly difficult in terms of time complexity
##df_red.to_csv('Historic_RealEstate_Data.csv', index = True)
# Out:
# Enter DB Password········
# Enter Wallet Password········
# Successfully connected to Oracle Database
# Successfully imported data

# %%
import pandas as pd
import numpy as np
import logging
from geopy.geocoders import Nominatim
import time


# Define functions for geolocation
geolocator = Nominatim(user_agent="MU-DS-Capstone")
def fix_address(address):
    #Error catching
    #Not-string error
    address = str(address)
    # Remove city
    if "," in address:
        address = address[:address.index(",")].strip()
    # If intersection, just use first street. TODO: Improve this
    if "/" in address:
        address = address[:address.index("/")].strip()
    # Remove NA values
    if pd.isna(address):
        address = np.nan
    # Change block address to just be that address number
    address = address.replace("-BLK", "")
    # Catching the BLVD error, needs to say BLVD not BL
    if address.endswith("BL"):
        address += "VD"
    # Catching MLK DR error, use old name
    address = address.replace("MARTIN L KING JR DR", "OLD WORLD THIRD ST")
    # Layton Error
    address = address.replace("S LAYTON ST", "S LAYTON BLVD")
    # Leon Error
    address = address.replace("LEON TR", "LEON TERRACE")
    # Mc Kinley Error
    address = address.replace("MC KINLEY", "MCKINLEY")
    # W Fond Du Lac Error
    if "FOND DU LAC" in address and "AV" not in address:
        address = address.replace("FOND DU LAC", "FOND DU LAC AV")
    # Bluemound road error
    address = address.replace("BLUE MOUND RD", "BLUEMOUND RD")        
    return address + " MILWAUKEE"

def geocode(address):
    try:
        geocoded = geolocator.geocode(address)
        return geocoded
    except Exception as e:
        logging.warning("Error geocoding", e)

def get_gps(geocoded, index):
    if geocoded is None:
        return np.nan
    gps = geocoded[1][index]
    if index == 0 and abs(gps - 43.0389) > 1:
        return np.nan
    elif index == 1 and abs(gps + 87.9065) > 1:
        return np.nan  
    return geocoded[1][index]


    
    
# Add Latitude and Longitude columns to dataframe
print('Fixing Addresses.')
start = time.process_time()
fixed_addresses = df_red.Address.transform(fix_address)
print('Addresses Fixed. Time Elapsed:')
print(time.process_time() - start)

print('Geocoding Addresses.')
start = time.process_time()
geocoded_addresses = fixed_addresses.apply(geocode)
print('Addresses Geocoded. Time Elapsed:')
print(time.process_time() - start)

print('Filling Latitude Column.')
start = time.process_time()
df_red["Latitude"] = geocoded_addresses.apply(get_gps, index=0)
print('Latitiude Column Full. Time Elapsed:')
print(time.process_time() - start)

print('Filling Longitude Column.')
start = time.process_time()
df_red["Longitude"] = geocoded_addresses.apply(get_gps, index=1)
print('Longitude Column Full. Time Elapsed:')
print(time.process_time() - start)
# Out:
# Fixing Addresses.
# Addresses Fixed. Time Elapsed:
# 0.07125030000000265
# Geocoding Addresses.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 1040, in _validate_conn
#     conn.connect()
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connection.py", line 426, in connect
#     tls_in_tls=tls_in_tls,
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/util/ssl_.py", line 450, in ssl_wrap_socket
#     sock, context, tls_in_tls, server_hostname=server_hostname
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/util/ssl_.py", line 493, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/usr/lib/python3.7/ssl.py", line 423, in wrap_socket
#     session=session
#   File "/usr/lib/python3.7/ssl.py", line 870, in _create
#     self.do_handshake()
#   File "/usr/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# socket.timeout: _ssl.c:1074: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 710, in urlopen
#     chunked=chunked,
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 389, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 341, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/adapters.py", line 450, in send
#     timeout=timeout
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     **response_kw
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     **response_kw
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 786, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2911+N+6TH+ST+MILWAUKEE&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/adapters.py", line 457, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/sessions.py", line 542, in get
#     return self.request('GET', url, **kwargs)
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2911+N+6TH+ST+MILWAUKEE&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_82/1520281569.py", line 46, in geocode
#     geocoded = geolocator.geocode(address)
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/adapters.py", line 469, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=2911+N+6TH+ST+MILWAUKEE&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/logan/py37/lib/python3.7/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "/home/logan/py37/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2958, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3003, in _run_cell
#     return runner(coro)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3229, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_82/1520281569.py", line 73, in <module>
#     geocoded_addresses = fixed_addresses.apply(geocode)
#   File "/home/logan/py37/lib/python3.7/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/logan/py37/lib/python3.7/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/logan/py37/lib/python3.7/site-packages/pandas/core/apply.py", line 1101, in apply_standard
#     convert=self.convert_dtype,
#   File "/tmp/ipykernel_82/1520281569.py", line 49, in geocode
#     logging.warning("Error geocoding", e)
# Message: 'Error geocoding'
# Arguments: (GeocoderUnavailable('HTTPSConnectionPool(host=\'nominatim.openstreetmap.org\', port=443): Max retries exceeded with url: /search?q=2911+N+6TH+ST+MILWAUKEE&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host=\'nominatim.openstreetmap.org\', port=443): Read timed out. (read timeout=1)"))'),)
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=8069+W+MANOR+CR+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5843+W+ELLIOTT+CR+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=8038+W+MANOR+CR+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=8309-E+N+107TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4073+N+46TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=6322+N+77TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=6322+N+77TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5649-5651+N+90TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5649-5651+N+90TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4241+W+WILLOW+WA+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2024+S+7TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2745+N+BUFFUM+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=426+S+91ST+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=7841-E+N+60TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=6500+W+CALUMET+RD+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5373+N+39TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5056+N+19TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4123+W+FAIRMOUNT+AV+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4979+N+54TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4902+N+72ND+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5044-5046+N+84TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=8537+W+LAWRENCE+AV+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2963+S+51ST+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3424+W+KINNICKINNIC+RIVER+PK+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2251-2253+N+41ST+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1830+N+14TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=8301+W+BURLEIGH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3224+N+87TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3224+N+87TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3378+S+71ST+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5812+W+ELLIOTT+CR+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2971+S+46TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3228-3230+N+30TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2611-2613+N+47TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=11535+W+BRITTANY+WA+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4818+W+WELLS+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4408+S+QUINCY+AV+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=617+E+WISCONSIN+AV+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=6292+S+27TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=7354+N+BISHOP+CR+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5939-A+N+37TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4225+W+WILLOW+WA+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4234+W+WILLOW+WA+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1809-302+N+COMMERCE+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=7434+W+GEORGIA+CT+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1663+S+28TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5939--B+N+40TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=234-213+N+BROADWAY+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=234-602+N+BROADWAY+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1809-103+N+COMMERCE+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=7354+N+BISHOP+CR+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=201-229+W+CHERRY+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=201-229+W+CHERRY+ST+MILWAUKEE&format=json&limit=1
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/usr/lib/python3.7/http/client.py", line 1373, in getresponse
#     response.begin()
#   File "/usr/lib/python3.7/http/client.py", line 319, in begin
#     version, status, reason = self._read_status()
#   File "/usr/lib/python3.7/http/client.py", line 280, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/usr/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.7/ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.7/ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 710, in urlopen
#     chunked=chunked,
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 341, in _raise_timeout
#     self, url, "Read timed out. (read timeout=%s)" % timeout_value
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/adapters.py", line 450, in send
#     timeout=timeout
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     **response_kw
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     **response_kw
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/connectionpool.py", line 786, in urlopen
#     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#   File "/home/logan/py37/lib/python3.7/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=201-229+W+CHERRY+ST+MILWAUKEE&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/adapters.py", line 457, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/sessions.py", line 542, in get
#     return self.request('GET', url, **kwargs)
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/logan/py37/lib/python3.7/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=201-229+W+CHERRY+ST+MILWAUKEE&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_82/1520281569.py", line 46, in geocode
#     geocoded = geolocator.geocode(address)
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/home/logan/py37/lib/python3.7/site-packages/geopy/adapters.py", line 469, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=201-229+W+CHERRY+ST+MILWAUKEE&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/logging/__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.7/logging/__init__.py", line 869, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.7/logging/__init__.py", line 608, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.7/logging/__init__.py", line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/logan/py37/lib/python3.7/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "/home/logan/py37/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#     handle._run()
#   File "/usr/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/logan/py37/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2958, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3003, in _run_cell
#     return runner(coro)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3229, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/logan/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3524, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_82/1520281569.py", line 73, in <module>
#     geocoded_addresses = fixed_addresses.apply(geocode)
#   File "/home/logan/py37/lib/python3.7/site-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "/home/logan/py37/lib/python3.7/site-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#   File "/home/logan/py37/lib/python3.7/site-packages/pandas/core/apply.py", line 1101, in apply_standard
#     convert=self.convert_dtype,
#   File "/tmp/ipykernel_82/1520281569.py", line 49, in geocode
#     logging.warning("Error geocoding", e)
# Message: 'Error geocoding'
# Arguments: (GeocoderUnavailable('HTTPSConnectionPool(host=\'nominatim.openstreetmap.org\', port=443): Max retries exceeded with url: /search?q=201-229+W+CHERRY+ST+MILWAUKEE&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host=\'nominatim.openstreetmap.org\', port=443): Read timed out. (read timeout=1)"))'),)
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=234-212+N+BROADWAY+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=8322-3+W+HOWARD+AV+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2963-2965+N+12TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=2417-2417A+N+OAKLAND+AV+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3262-3264+N+CAMBRIDGE+AV+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=8338-4+W+HOWARD+AV+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3179+S+77TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=8309--L+N+107TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4912--E+S+19TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5201-N+S+13TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5213-F+S+13TH+ST+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4215+W+WILLOW+WA+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=7354+N+BISHOP+CR+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=11535+W+BRITTANY+WA+MILWAUKEE&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5939--A+N+37TH+ST+MILWAUKEE&format=json&limit=1
# Addresses Geocoded. Time Elapsed:
# 197.5781345
# Filling Latitude Column.
# Latitiude Column Full. Time Elapsed:
# 0.09240909999999758
# Filling Longitude Column.
# Longitude Column Full. Time Elapsed:
# 0.05395849999999314

# %%
new_columns = ['Latitude','Longitude']
df_red.loc[:,new_columns] = pd.DataFrame()
# Out:
#       PropertyID     PropType            Address  District Sale_date  \
# 0           None  Condominium  1924 N HUBBARD ST       6.0   2011-06
# 1           None  Condominium  1550 E ROYALL  PL       3.0   2011-06
# 2           None  Condominium  3749105 N 88TH ST       5.0   2011-06
# 3           None  Condominium     130 S WATER ST      12.0   2011-06
# 4           None  Condominium  2302 E WYOMING PL       3.0   2011-06
# ...          ...          ...                ...       ...       ...
# 59688       None  Residential     3770 S 78TH ST      11.0   2017-04
# 59689       None  Residential   3625 S SUNSET DR      11.0   2017-04
# 59690       None  Residential     2780 S 64TH ST      11.0   2017-04
# 59691       None  Residential     3318 S 73RD ST      11.0   2017-04
# 59692       None  Residential     2553 S 64TH ST      11.0   2017-04
#
#        Sale_price  Latitude  Longitude
# 0        225490.0       NaN        NaN
# 1        236750.0       NaN        NaN
# 2         57500.0       NaN        NaN
# 3        410000.0       NaN        NaN
# 4        130000.0       NaN        NaN
# ...           ...       ...        ...
# 59688    143155.0       NaN        NaN
# 59689    127500.0       NaN        NaN
# 59690    141000.0       NaN        NaN
# 59691    135900.0       NaN        NaN
# 59692    140000.0       NaN        NaN
#
# [59693 rows x 8 columns]

# %%
df_red.to_csv('Historic_RealEstate_Data.csv', index = True)
