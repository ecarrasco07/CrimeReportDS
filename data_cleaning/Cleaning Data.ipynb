# %%
##Logan l.
##Clean data

##importing required packages for this exploratory data analysis
import pandas as pd

##importing the csvs as dfs
df22 = pd.read_csv("armslengthsales_2022_valid.csv")
df21 = pd.read_csv("armslengthsales_2021_valid.csv")
df20 = pd.read_csv("armslengthsales_2020_valid.csv")
df19 = pd.read_csv("2019-property-sales-data.csv")
df18 = pd.read_csv("2018-property-sales-data.csv")
df17 = pd.read_csv("2017-property-sales-data.csv")
df16 = pd.read_csv("2016-property-sales-data.csv")
df15 = pd.read_csv("2015-property-sales-data.csv")
df14 = pd.read_csv("2014-property-sales-data.csv")
df13 = pd.read_csv("2013-property-sales-data.csv")
df12 = pd.read_csv("2012-property-sales-data.csv")
df11 = pd.read_csv("2011-property-sales-data.csv")
df10 = pd.read_csv("2010-property-sales-data.csv")
df09 = pd.read_csv("2009-property-sales-data.csv")
df08 = pd.read_csv("2008-property-sales-data.csv")
df07 = pd.read_csv("2007-property-sales-data.csv")
df06 = pd.read_csv("2006-property-sales-data.csv")
df05 = pd.read_csv("2005-property-sales-data.csv")

##removal of unwanted data
df22 = df22[['PropertyID', 'PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df21 = df21[['PropertyID', 'PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df20 = df20[['PropertyID', 'PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df19 = df19[['PropertyID', 'PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df18 = df18[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df17 = df17[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df16 = df16[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df15 = df15[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df14 = df14[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df13 = df13[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df12 = df12[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df11 = df11[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df10 = df10[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df09 = df09[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df08 = df08[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df07 = df07[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df06 = df06[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]
df05 = df05[['PropType', 'Address', 'District', 'Sale_date', 'Sale_price']]

##exporting clean dfs as csvs
df22.to_csv('HistoricRealEstate(2022).csv', index = True)
df21.to_csv('HistoricRealEstate(2021).csv', index = True)
df20.to_csv('HistoricRealEstate(2020).csv', index = True)
df19.to_csv('HistoricRealEstate(2019).csv', index = True)
df18.to_csv('HistoricRealEstate(2018).csv', index = True)
df17.to_csv('HistoricRealEstate(2017).csv', index = True)
df16.to_csv('HistoricRealEstate(2016).csv', index = True)
df15.to_csv('HistoricRealEstate(2015).csv', index = True)
df14.to_csv('HistoricRealEstate(2014).csv', index = True)
df13.to_csv('HistoricRealEstate(2013).csv', index = True)
df12.to_csv('HistoricRealEstate(2012).csv', index = True)
df11.to_csv('HistoricRealEstate(2011).csv', index = True)
df10.to_csv('HistoricRealEstate(2010).csv', index = True)
df09.to_csv('HistoricRealEstate(2009).csv', index = True)
df08.to_csv('HistoricRealEstate(2008).csv', index = True)
df07.to_csv('HistoricRealEstate(2007).csv', index = True)
df06.to_csv('HistoricRealEstate(2006).csv', index = True)
df05.to_csv('HistoricRealEstate(2005).csv', index = True)
